# %%
#Naive Bayes for spam filtering
import numpy as np
import pandas as pd
import os
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
flist = os.listdir("./enron1/ham")
data = []
target = []
index = []
rows = []
for f in flist[:100]:
    ifile=open("./enron1/ham/"+f)
    text = ""
    lines = ifile.readlines()
    for l in lines:
        text = text + l
    ifile.close()
    rows.append({'text': text, 'class': 0})
    index.append(f)
    #data.append(text)
    #target.append("ham")
flist = os.listdir("enron1\\spam")
for f in flist[:100]:
    ifile=open("enron1\\spam\\"+f)
    text = ""
    lines = ifile.readlines()
    for l in lines:
        text = text + l
    ifile.close()
    rows.append({'text': text, 'class': 1})
    index.append(f)
    #data.append(text)
    #target.append("spam")
data_frame = pd.DataFrame(rows, index=index)
#count_vectorizer = CountVectorizer()
counts = count_vectorizer.fit_transform(data_frame['text'])
transformer = TfidfTransformer()
tfidf = transformer.fit_transform(counts)
classifier = MultinomialNB()
targets = data_frame['class'].values
classifier.fit(tfidf, targets)
examples = ['Make money for free', "I'm going to attend the Linux users group tomorrow."]
example_counts = count_vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f22df358183e> in <module>()
#       6 from sklearn.naive_bayes import MultinomialNB
#       7 from sklearn.feature_extraction.text import TfidfTransformer
# ----> 8 flist = os.listdir("enron1\\ham")
#       9 data = []
#      10 target = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'enron1\\ham'

# %%
#K-MEANS for image compression
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %pylab inline
from sklearn import cluster
from scipy import misc
face = misc.face(gray=True)
#plt.imshow(face,cmap=plt.cm.gray)
n_clusters = 4

X = face.reshape((-1, 1))  # We need an (n_sample, n_feature) array
k_means = cluster.KMeans(n_clusters=n_clusters, n_init=4)
k_means.fit(X)
values = k_means.cluster_centers_.squeeze()
labels = k_means.labels_
values
face_compressed = np.choose(labels, values)
face_compressed.shape = face.shape

vmin = face.min()
vmax = face.max()

# original face
plt.figure(1, figsize=(3, 2.2))
plt.imshow(face, cmap=plt.cm.gray, vmin=vmin, vmax=256)

# compressed face
plt.figure(2, figsize=(3, 2.2))
plt.imshow(face_compressed, cmap=plt.cm.gray, vmin=vmin, vmax=vmax)
# Out:
# Populating the interactive namespace from numpy and matplotlib
